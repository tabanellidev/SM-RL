# %%
import gym

#Import game
import gym_super_mario_bros

#Import Joypad
from nes_py.wrappers import JoypadSpace

#Import Controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

#FrameStacking e GreyScaling
from gym.wrappers import GrayScaleObservation

#Vectorization
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv

#Graphs
from matplotlib import pyplot as plt

import os

from stable_baselines3 import DQN

#To save models
from stable_baselines3.common.callbacks import BaseCallback

from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

import torch.nn as nn
import torch as th

from gymnasium import spaces

# %%
# [1] - Setup base environment
env = gym_super_mario_bros.make("SuperMarioBros-v0", render_mode='human', apply_api_compatibility=True)
#256 possible actions
print(env.action_space)

# [2] - Simplify the controls, with wrapping the model will have only 7 possible actions
env = JoypadSpace(env, [["right"], ["right", "A"]])
print(env.action_space)

# [3] - Grayscale
env = GrayScaleObservation(env, keep_dim=True)

# [4] - Wrap inside a dummy envorinment
env = DummyVecEnv([lambda: env])

# [5] - Stack four frames
env = VecFrameStack(env, 4, channels_order='last')

#JoypadSpace doesn't correctly override the reset() method of Wrapper.
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
# Out:
# Discrete(256)
# Discrete(2)
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
checkpoint_directory = './train/'
log_dir = './logs/'

callback = TrainAndLoggingCallback(check_freq=100000,save_path=checkpoint_directory)

# %%
model = DQN('CnnPolicy', env, verbose=1, tensorboard_log=log_dir, learning_rate=0.00004, batch_size=250, learning_starts=5000, buffer_size=5000)

print(model.policy)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# CnnPolicy(
#   (q_net): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=46592, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=2, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=46592, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=2, bias=True)
#     )
#   )
# )

# %%
model.learn(total_timesteps=3500000, callback=callback)
# Out:
# Logging to ./logs/DQN_1
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 55       |
# |    time_elapsed     | 630      |
# |    total_timesteps  | 35214    |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0464   |
# |    n_updates        | 7553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 49       |
# |    time_elapsed     | 1936     |
# |    total_timesteps  | 95370    |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0275   |
# |    n_updates        | 22592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 46       |
# |    time_elapsed     | 3356     |
# |    total_timesteps  | 156474   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0621   |
# |    n_updates        | 37868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 45       |
# |    time_elapsed     | 4672     |
# |    total_timesteps  | 210433   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.148    |
# |    n_updates        | 51358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 44       |
# |    time_elapsed     | 5666     |
# |    total_timesteps  | 250759   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.109    |
# |    n_updates        | 61439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 44       |
# |    time_elapsed     | 6061     |
# |    total_timesteps  | 266771   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.272    |
# |    n_updates        | 65442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 43       |
# |    time_elapsed     | 6595     |
# |    total_timesteps  | 288102   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0353   |
# |    n_updates        | 70775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 43       |
# |    time_elapsed     | 7136     |
# |    total_timesteps  | 309718   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.126    |
# |    n_updates        | 76179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.123    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 43       |
# |    time_elapsed     | 7471     |
# |    total_timesteps  | 322966   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0752   |
# |    n_updates        | 79491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0697   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 43       |
# |    time_elapsed     | 7969     |
# |    total_timesteps  | 342732   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.182    |
# |    n_updates        | 84432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 42       |
# |    time_elapsed     | 8603     |
# |    total_timesteps  | 367897   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.13     |
# |    n_updates        | 90724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 42       |
# |    time_elapsed     | 9179     |
# |    total_timesteps  | 390480   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0783   |
# |    n_updates        | 96369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 42       |
# |    time_elapsed     | 9389     |
# |    total_timesteps  | 398785   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.366    |
# |    n_updates        | 98446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 42       |
# |    time_elapsed     | 9769     |
# |    total_timesteps  | 413542   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.222    |
# |    n_updates        | 102135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 42       |
# |    time_elapsed     | 10392    |
# |    total_timesteps  | 438054   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.114    |
# |    n_updates        | 108263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 42       |
# |    time_elapsed     | 10527    |
# |    total_timesteps  | 443486   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.199    |
# |    n_updates        | 109621   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 41       |
# |    time_elapsed     | 11431    |
# |    total_timesteps  | 479579   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.167    |
# |    n_updates        | 118644   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 41       |
# |    time_elapsed     | 11865    |
# |    total_timesteps  | 496625   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.183    |
# |    n_updates        | 122906   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 41       |
# |    time_elapsed     | 12321    |
# |    total_timesteps  | 514744   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.335    |
# |    n_updates        | 127435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 41       |
# |    time_elapsed     | 13214    |
# |    total_timesteps  | 550302   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.211    |
# |    n_updates        | 136325   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 41       |
# |    time_elapsed     | 13739    |
# |    total_timesteps  | 571119   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.108    |
# |    n_updates        | 141529   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 41       |
# |    time_elapsed     | 14288    |
# |    total_timesteps  | 592820   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.188    |
# |    n_updates        | 146954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 41       |
# |    time_elapsed     | 14591    |
# |    total_timesteps  | 604929   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0719   |
# |    n_updates        | 149982   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 41       |
# |    time_elapsed     | 15005    |
# |    total_timesteps  | 621712   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.497    |
# |    n_updates        | 154177   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 41       |
# |    time_elapsed     | 15438    |
# |    total_timesteps  | 639073   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0895   |
# |    n_updates        | 158518   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 41       |
# |    time_elapsed     | 15697    |
# |    total_timesteps  | 649511   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.361    |
# |    n_updates        | 161127   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 41       |
# |    time_elapsed     | 15892    |
# |    total_timesteps  | 657447   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.195    |
# |    n_updates        | 163111   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 41       |
# |    time_elapsed     | 16189    |
# |    total_timesteps  | 669387   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.266    |
# |    n_updates        | 166096   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 41       |
# |    time_elapsed     | 16410    |
# |    total_timesteps  | 678233   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.784    |
# |    n_updates        | 168308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 41       |
# |    time_elapsed     | 16645    |
# |    total_timesteps  | 687824   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.103    |
# |    n_updates        | 170705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 41       |
# |    time_elapsed     | 16980    |
# |    total_timesteps  | 701256   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.175    |
# |    n_updates        | 174063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 41       |
# |    time_elapsed     | 17335    |
# |    total_timesteps  | 715528   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.226    |
# |    n_updates        | 177631   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 41       |
# |    time_elapsed     | 17818    |
# |    total_timesteps  | 735181   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0527   |
# |    n_updates        | 182545   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 41       |
# |    time_elapsed     | 18046    |
# |    total_timesteps  | 744382   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.423    |
# |    n_updates        | 184845   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 41       |
# |    time_elapsed     | 18286    |
# |    total_timesteps  | 754014   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.569    |
# |    n_updates        | 187253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 41       |
# |    time_elapsed     | 18656    |
# |    total_timesteps  | 769082   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.165    |
# |    n_updates        | 191020   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 41       |
# |    time_elapsed     | 19242    |
# |    total_timesteps  | 792631   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.136    |
# |    n_updates        | 196907   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 41       |
# |    time_elapsed     | 19821    |
# |    total_timesteps  | 816078   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.328    |
# |    n_updates        | 202769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 41       |
# |    time_elapsed     | 19956    |
# |    total_timesteps  | 821504   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.273    |
# |    n_updates        | 204125   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 41       |
# |    time_elapsed     | 20281    |
# |    total_timesteps  | 834721   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.317    |
# |    n_updates        | 207430   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 41       |
# |    time_elapsed     | 20481    |
# |    total_timesteps  | 842817   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.372    |
# |    n_updates        | 209454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 41       |
# |    time_elapsed     | 20669    |
# |    total_timesteps  | 850390   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.311    |
# |    n_updates        | 211347   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 41       |
# |    time_elapsed     | 21091    |
# |    total_timesteps  | 867447   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.339    |
# |    n_updates        | 215611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 41       |
# |    time_elapsed     | 21331    |
# |    total_timesteps  | 877257   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.35     |
# |    n_updates        | 218064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 41       |
# |    time_elapsed     | 21560    |
# |    total_timesteps  | 886475   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.413    |
# |    n_updates        | 220368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 41       |
# |    time_elapsed     | 21680    |
# |    total_timesteps  | 891289   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.532    |
# |    n_updates        | 221572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 41       |
# |    time_elapsed     | 21833    |
# |    total_timesteps  | 897441   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.339    |
# |    n_updates        | 223110   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 41       |
# |    time_elapsed     | 22066    |
# |    total_timesteps  | 906873   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.804    |
# |    n_updates        | 225468   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 41       |
# |    time_elapsed     | 22327    |
# |    total_timesteps  | 917420   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.283    |
# |    n_updates        | 228104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 41       |
# |    time_elapsed     | 22569    |
# |    total_timesteps  | 927125   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.3      |
# |    n_updates        | 230531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 41       |
# |    time_elapsed     | 23272    |
# |    total_timesteps  | 956018   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.204    |
# |    n_updates        | 237754   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 41       |
# |    time_elapsed     | 23541    |
# |    total_timesteps  | 967154   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.34     |
# |    n_updates        | 240538   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 41       |
# |    time_elapsed     | 23741    |
# |    total_timesteps  | 975477   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.509    |
# |    n_updates        | 242619   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 41       |
# |    time_elapsed     | 23945    |
# |    total_timesteps  | 983852   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.324    |
# |    n_updates        | 244712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 41       |
# |    time_elapsed     | 24373    |
# |    total_timesteps  | 1001092  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0418   |
# |    n_updates        | 249022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 41       |
# |    time_elapsed     | 24561    |
# |    total_timesteps  | 1008624  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.525    |
# |    n_updates        | 250905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 41       |
# |    time_elapsed     | 24958    |
# |    total_timesteps  | 1024706  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.244    |
# |    n_updates        | 254926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 41       |
# |    time_elapsed     | 25071    |
# |    total_timesteps  | 1029267  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.457    |
# |    n_updates        | 256066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 41       |
# |    time_elapsed     | 25267    |
# |    total_timesteps  | 1037148  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.383    |
# |    n_updates        | 258036   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 41       |
# |    time_elapsed     | 25399    |
# |    total_timesteps  | 1042456  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.291    |
# |    n_updates        | 259363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 41       |
# |    time_elapsed     | 25783    |
# |    total_timesteps  | 1058188  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.153    |
# |    n_updates        | 263296   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 41       |
# |    time_elapsed     | 26030    |
# |    total_timesteps  | 1068393  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.824    |
# |    n_updates        | 265848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 41       |
# |    time_elapsed     | 26292    |
# |    total_timesteps  | 1079119  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.309    |
# |    n_updates        | 268529   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 41       |
# |    time_elapsed     | 26486    |
# |    total_timesteps  | 1086873  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.178    |
# |    n_updates        | 270468   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 41       |
# |    time_elapsed     | 26670    |
# |    total_timesteps  | 1094386  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.492    |
# |    n_updates        | 272346   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 41       |
# |    time_elapsed     | 26909    |
# |    total_timesteps  | 1103975  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.316    |
# |    n_updates        | 274743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 41       |
# |    time_elapsed     | 27059    |
# |    total_timesteps  | 1109992  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.35     |
# |    n_updates        | 276247   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 41       |
# |    time_elapsed     | 27282    |
# |    total_timesteps  | 1118923  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.328    |
# |    n_updates        | 278480   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 41       |
# |    time_elapsed     | 27443    |
# |    total_timesteps  | 1125467  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.295    |
# |    n_updates        | 280116   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 41       |
# |    time_elapsed     | 27623    |
# |    total_timesteps  | 1132819  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 281954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 41       |
# |    time_elapsed     | 27795    |
# |    total_timesteps  | 1139707  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.401    |
# |    n_updates        | 283676   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 41       |
# |    time_elapsed     | 27917    |
# |    total_timesteps  | 1144610  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.29     |
# |    n_updates        | 284902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 40       |
# |    time_elapsed     | 28107    |
# |    total_timesteps  | 1152238  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.369    |
# |    n_updates        | 286809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 40       |
# |    time_elapsed     | 28417    |
# |    total_timesteps  | 1164892  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.445    |
# |    n_updates        | 289972   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 40       |
# |    time_elapsed     | 28680    |
# |    total_timesteps  | 1175501  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.606    |
# |    n_updates        | 292625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 40       |
# |    time_elapsed     | 28776    |
# |    total_timesteps  | 1179318  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.516    |
# |    n_updates        | 293579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 40       |
# |    time_elapsed     | 28969    |
# |    total_timesteps  | 1187071  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.194    |
# |    n_updates        | 295517   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 40       |
# |    time_elapsed     | 29270    |
# |    total_timesteps  | 1199191  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.129    |
# |    n_updates        | 298547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 40       |
# |    time_elapsed     | 29411    |
# |    total_timesteps  | 1204900  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.3      |
# |    n_updates        | 299974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 40       |
# |    time_elapsed     | 29657    |
# |    total_timesteps  | 1215047  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.24     |
# |    n_updates        | 302511   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 40       |
# |    time_elapsed     | 29886    |
# |    total_timesteps  | 1224380  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.265    |
# |    n_updates        | 304844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 40       |
# |    time_elapsed     | 30054    |
# |    total_timesteps  | 1231208  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.678    |
# |    n_updates        | 306551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 40       |
# |    time_elapsed     | 30429    |
# |    total_timesteps  | 1246628  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.105    |
# |    n_updates        | 310406   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 40       |
# |    time_elapsed     | 30612    |
# |    total_timesteps  | 1254065  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.449    |
# |    n_updates        | 312266   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 40       |
# |    time_elapsed     | 30863    |
# |    total_timesteps  | 1264265  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.375    |
# |    n_updates        | 314816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 40       |
# |    time_elapsed     | 31066    |
# |    total_timesteps  | 1272566  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.355    |
# |    n_updates        | 316891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 40       |
# |    time_elapsed     | 31254    |
# |    total_timesteps  | 1280309  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.589    |
# |    n_updates        | 318827   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 40       |
# |    time_elapsed     | 31615    |
# |    total_timesteps  | 1294752  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.215    |
# |    n_updates        | 322437   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 40       |
# |    time_elapsed     | 31758    |
# |    total_timesteps  | 1300506  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.808    |
# |    n_updates        | 323876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 40       |
# |    time_elapsed     | 32038    |
# |    total_timesteps  | 1311795  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.553    |
# |    n_updates        | 326698   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 40       |
# |    time_elapsed     | 32207    |
# |    total_timesteps  | 1318461  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.603    |
# |    n_updates        | 328365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 40       |
# |    time_elapsed     | 32576    |
# |    total_timesteps  | 1332890  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.144    |
# |    n_updates        | 331972   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 40       |
# |    time_elapsed     | 32678    |
# |    total_timesteps  | 1336907  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.36     |
# |    n_updates        | 332976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 40       |
# |    time_elapsed     | 32957    |
# |    total_timesteps  | 1347783  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.189    |
# |    n_updates        | 335695   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 40       |
# |    time_elapsed     | 33074    |
# |    total_timesteps  | 1352303  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.375    |
# |    n_updates        | 336825   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 40       |
# |    time_elapsed     | 33185    |
# |    total_timesteps  | 1356617  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.286    |
# |    n_updates        | 337904   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 40       |
# |    time_elapsed     | 33451    |
# |    total_timesteps  | 1366928  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.433    |
# |    n_updates        | 340481   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 40       |
# |    time_elapsed     | 33588    |
# |    total_timesteps  | 1372254  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.243    |
# |    n_updates        | 341813   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 40       |
# |    time_elapsed     | 34000    |
# |    total_timesteps  | 1388450  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.266    |
# |    n_updates        | 345862   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 40       |
# |    time_elapsed     | 34138    |
# |    total_timesteps  | 1393976  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.736    |
# |    n_updates        | 347243   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 40       |
# |    time_elapsed     | 34323    |
# |    total_timesteps  | 1401174  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.45     |
# |    n_updates        | 349043   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 40       |
# |    time_elapsed     | 34763    |
# |    total_timesteps  | 1418346  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.219    |
# |    n_updates        | 353336   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 40       |
# |    time_elapsed     | 34884    |
# |    total_timesteps  | 1423058  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.722    |
# |    n_updates        | 354514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 40       |
# |    time_elapsed     | 34959    |
# |    total_timesteps  | 1426000  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.213    |
# |    n_updates        | 355249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 40       |
# |    time_elapsed     | 35059    |
# |    total_timesteps  | 1429894  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.251    |
# ...
# |    n_updates        | 395945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 40       |
# |    time_elapsed     | 39335    |
# |    total_timesteps  | 1598743  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.426    |
# |    n_updates        | 398435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 40       |
# |    time_elapsed     | 39454    |
# |    total_timesteps  | 1603551  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.389    |
# |    n_updates        | 399637   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 40       |
# |    time_elapsed     | 39631    |
# |    total_timesteps  | 1610701  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.843    |
# |    n_updates        | 401425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 40       |
# |    time_elapsed     | 39834    |
# |    total_timesteps  | 1619025  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.492    |
# |    n_updates        | 403506   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 40       |
# |    time_elapsed     | 40012    |
# |    total_timesteps  | 1626191  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.753    |
# |    n_updates        | 405297   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 40       |
# |    time_elapsed     | 40201    |
# |    total_timesteps  | 1633800  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.304    |
# |    n_updates        | 407199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 40       |
# |    time_elapsed     | 40557    |
# |    total_timesteps  | 1647674  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.482    |
# |    n_updates        | 410668   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 40       |
# |    time_elapsed     | 40882    |
# |    total_timesteps  | 1660421  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.799    |
# |    n_updates        | 413855   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 40       |
# |    time_elapsed     | 41132    |
# |    total_timesteps  | 1670098  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.939    |
# |    n_updates        | 416274   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 40       |
# |    time_elapsed     | 41304    |
# |    total_timesteps  | 1676815  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.361    |
# |    n_updates        | 417953   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 40       |
# |    time_elapsed     | 41496    |
# |    total_timesteps  | 1684234  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.53     |
# |    n_updates        | 419808   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 40       |
# |    time_elapsed     | 41678    |
# |    total_timesteps  | 1691347  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.723    |
# |    n_updates        | 421586   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 40       |
# |    time_elapsed     | 41906    |
# |    total_timesteps  | 1700364  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.912    |
# |    n_updates        | 423840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 40       |
# |    time_elapsed     | 42365    |
# |    total_timesteps  | 1718180  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.444    |
# |    n_updates        | 428294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 40       |
# |    time_elapsed     | 42541    |
# |    total_timesteps  | 1724983  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.394    |
# |    n_updates        | 429995   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 40       |
# |    time_elapsed     | 42765    |
# |    total_timesteps  | 1733718  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.377    |
# |    n_updates        | 432179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 40       |
# |    time_elapsed     | 43177    |
# |    total_timesteps  | 1749952  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.303    |
# |    n_updates        | 436237   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 40       |
# |    time_elapsed     | 43501    |
# |    total_timesteps  | 1762602  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.376    |
# |    n_updates        | 439400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 40       |
# |    time_elapsed     | 44060    |
# |    total_timesteps  | 1784557  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.337    |
# |    n_updates        | 444889   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 40       |
# |    time_elapsed     | 44413    |
# |    total_timesteps  | 1798494  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.252    |
# |    n_updates        | 448373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 40       |
# |    time_elapsed     | 45147    |
# |    total_timesteps  | 1827240  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.237    |
# |    n_updates        | 455559   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 40       |
# |    time_elapsed     | 45369    |
# |    total_timesteps  | 1835940  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.371    |
# |    n_updates        | 457734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 40       |
# |    time_elapsed     | 45926    |
# |    total_timesteps  | 1858071  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.226    |
# |    n_updates        | 463267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 40       |
# |    time_elapsed     | 45996    |
# |    total_timesteps  | 1860963  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.432    |
# |    n_updates        | 463990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 40       |
# |    time_elapsed     | 46315    |
# |    total_timesteps  | 1873935  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.408    |
# |    n_updates        | 467233   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 40       |
# |    time_elapsed     | 47010    |
# |    total_timesteps  | 1902151  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.219    |
# |    n_updates        | 474287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 40       |
# |    time_elapsed     | 47271    |
# |    total_timesteps  | 1912289  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.331    |
# |    n_updates        | 476822   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 40       |
# |    time_elapsed     | 47847    |
# |    total_timesteps  | 1934900  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.239    |
# |    n_updates        | 482474   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 40       |
# |    time_elapsed     | 48094    |
# |    total_timesteps  | 1944525  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.396    |
# |    n_updates        | 484881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 40       |
# |    time_elapsed     | 48268    |
# |    total_timesteps  | 1951286  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.538    |
# |    n_updates        | 486571   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 40       |
# |    time_elapsed     | 48389    |
# |    total_timesteps  | 1956000  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.253    |
# |    n_updates        | 487749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 40       |
# |    time_elapsed     | 48522    |
# |    total_timesteps  | 1961162  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.392    |
# |    n_updates        | 489040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 40       |
# |    time_elapsed     | 48673    |
# |    total_timesteps  | 1967195  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.341    |
# |    n_updates        | 490548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 40       |
# |    time_elapsed     | 48863    |
# |    total_timesteps  | 1974536  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.412    |
# |    n_updates        | 492383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 40       |
# |    time_elapsed     | 49006    |
# |    total_timesteps  | 1980110  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.67     |
# |    n_updates        | 493777   |
# ----------------------------------
