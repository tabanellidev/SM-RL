# %%
import gym

#Import game
import gym_super_mario_bros

#Import Joypad
from nes_py.wrappers import JoypadSpace

#Import Controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

#FrameStacking e GreyScaling
from gym.wrappers import GrayScaleObservation

#Vectorization
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv

#Graphs
from matplotlib import pyplot as plt

import os

#Proximal Policy Optimization
from stable_baselines3 import PPO

#To save models
from stable_baselines3.common.callbacks import BaseCallback

import torch as th

# %%
# [1] - Setup base environment
env = gym_super_mario_bros.make("SuperMarioBros-v0", render_mode='human', apply_api_compatibility=True)
#256 possible actions
print(env.action_space)

# [2] - Simplify the controls, with wrapping the model will have only 7 possible actions
env = JoypadSpace(env, SIMPLE_MOVEMENT)
print(env.action_space)

# [3] - Grayscale
env = GrayScaleObservation(env, keep_dim=True)

# [4] - Wrap inside a dummy envorinment
env = DummyVecEnv([lambda: env])

# [5] - Stack four frames
env = VecFrameStack(env, 4, channels_order='last')

#JoypadSpace doesn't correctly override the reset() method of Wrapper.
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
# Out:
# Discrete(256)
# Discrete(7)
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
checkpoint_directory = './train/'
log_dir = './logs/'

callback = TrainAndLoggingCallback(check_freq=100000,save_path=checkpoint_directory)

# %%
policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=dict(pi=[32, 64, 64, 64], vf=[32, 64, 64, 64]))


model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_dir, learning_rate=0.0005,n_steps=4096,policy_kwargs=policy_kwargs)

model.policy
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# ActorCriticCnnPolicy(
#   (features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=46592, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=46592, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=46592, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=512, out_features=32, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=32, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=64, out_features=64, bias=True)
#       (7): ReLU()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=512, out_features=32, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=32, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=64, out_features=64, bias=True)
#       (7): ReLU()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=7, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
model.learn(total_timesteps=3500000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 168  |
# |    iterations      | 1    |
# |    time_elapsed    | 24   |
# |    total_timesteps | 4096 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 2           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013708018 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -0.00107    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.686       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 4.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 3           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004273616 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.853       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00026     |
# |    value_loss           | 2.03        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 4            |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036572032 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 1.03         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00665     |
# |    value_loss           | 5.8          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 5           |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006072394 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.18        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 4.47        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 6            |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0057778917 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.61         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000631    |
# |    value_loss           | 3.69         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 7           |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010120932 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.23        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -9.32e-05   |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 8           |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009143772 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.521       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000606   |
# |    value_loss           | 3.94        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 9           |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011999971 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.05        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 7.25        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 10          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008073224 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.298       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00161     |
# |    value_loss           | 1.57        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 11         |
# |    time_elapsed         | 438        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01262535 |
# |    clip_fraction        | 0.0794     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.891      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.000364  |
# |    value_loss           | 2.53       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 12          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012107714 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0949      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 0.487       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 13          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013712241 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.211       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 3.5         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 14           |
# |    time_elapsed         | 563          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0088074645 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0714       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 2.17         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 15          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008165518 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.631       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 16          |
# |    time_elapsed         | 644         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.034289986 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.129       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 0.85        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 17          |
# |    time_elapsed         | 685         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.013258638 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.19        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00151     |
# |    value_loss           | 2.16        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 18          |
# |    time_elapsed         | 725         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010019003 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.245       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 19          |
# |    time_elapsed         | 766         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.014000693 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.487       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00623    |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 20          |
# |    time_elapsed         | 807         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016289711 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0719      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000418   |
# |    value_loss           | 0.386       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 21          |
# |    time_elapsed         | 847         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013380973 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.181       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 22          |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008853737 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.306       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 23          |
# |    time_elapsed         | 927         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009627623 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.12        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000851    |
# |    value_loss           | 4.24        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 24          |
# |    time_elapsed         | 967         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009568194 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.307       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 1.36        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 25          |
# |    time_elapsed         | 1008        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011097949 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.195       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 1.39        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 101        |
# |    iterations           | 26         |
# |    time_elapsed         | 1050       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.00893376 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.74      |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.05       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00075   |
# |    value_loss           | 4.15       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 27          |
# |    time_elapsed         | 1091        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.014358657 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.284       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00383     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 28          |
# |    time_elapsed         | 1131        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.007941107 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.606       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -5.75e-05   |
# |    value_loss           | 2.32        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 29           |
# |    time_elapsed         | 1172         |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0076600723 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.293        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.000409     |
# |    value_loss           | 1.66         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 30           |
# |    time_elapsed         | 1213         |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0077653667 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 1.8          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000307     |
# |    value_loss           | 3.47         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 31          |
# |    time_elapsed         | 1253        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.008084145 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.168       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.000238    |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 32          |
# |    time_elapsed         | 1294        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.005649971 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.499       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 3.76        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 101        |
# |    iterations           | 33         |
# |    time_elapsed         | 1334       |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.01516944 |
# |    clip_fraction        | 0.0703     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.51      |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.193      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00355   |
# |    value_loss           | 1.42       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 101        |
# |    iterations           | 34         |
# |    time_elapsed         | 1375       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.00847773 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.633      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.000468   |
# |    value_loss           | 5.73       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 35          |
# |    time_elapsed         | 1416        |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.013667161 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.687       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 1.4         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 36          |
# |    time_elapsed         | 1458        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.007796307 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.447       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 1.59        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 37          |
# |    time_elapsed         | 1499        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.011967908 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.57        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 1.99        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 38          |
# |    time_elapsed         | 1540        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.013655958 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.444       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 2.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 39          |
# |    time_elapsed         | 1581        |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.011351819 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.227       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 1.05        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 40          |
# |    time_elapsed         | 1622        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009043833 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.376       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 1.92        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 41         |
# |    time_elapsed         | 1663       |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.01664205 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.201      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00586   |
# |    value_loss           | 1.16       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 42          |
# |    time_elapsed         | 1703        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.010535348 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.107       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00563    |
# |    value_loss           | 1.59        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 43          |
# |    time_elapsed         | 1744        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.013925353 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0444      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00513    |
# |    value_loss           | 0.584       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 44           |
# |    time_elapsed         | 1783         |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0053958585 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.575        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.000611     |
# |    value_loss           | 2.41         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 45          |
# |    time_elapsed         | 1824        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.014216068 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.121       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.772       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 46          |
# |    time_elapsed         | 1864        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011824404 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.533       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 7.08        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 47          |
# |    time_elapsed         | 1905        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.011843354 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.238       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 3.25        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 48          |
# |    time_elapsed         | 1945        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.022902664 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.245       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 49          |
# |    time_elapsed         | 1986        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.010024608 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.739       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 16          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 50           |
# |    time_elapsed         | 2027         |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0092059225 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.89         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00669     |
# |    value_loss           | 1.93         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 51          |
# |    time_elapsed         | 2068        |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.009208029 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.821       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 5.55        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 52          |
# |    time_elapsed         | 2108        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.012256002 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.145       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 0.789       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 53          |
# |    time_elapsed         | 2149        |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.008603933 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.118       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 1.54        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 54          |
# |    time_elapsed         | 2190        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.015281288 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.124       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.388       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 55           |
# |    time_elapsed         | 2231         |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0142198885 |
# |    clip_fraction        | 0.0906       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.662        |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 7.48         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 56          |
# |    time_elapsed         | 2272        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.017502498 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0254     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00995    |
# |    value_loss           | 0.13        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 57           |
# |    time_elapsed         | 2313         |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0068567116 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.282        |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 4.78         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 58          |
# |    time_elapsed         | 2353        |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.010058371 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.4         |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 9.87        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 59          |
# |    time_elapsed         | 2394        |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.013593199 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.214       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00855    |
# |    value_loss           | 0.814       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 60          |
# |    time_elapsed         | 2434        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.012525334 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.219       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0094     |
# |    value_loss           | 3.55        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 61          |
# |    time_elapsed         | 2474        |
# |    total_timesteps      | 249856      |
# | train/                  |             |
# |    approx_kl            | 0.014002068 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0805      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 62          |
# |    time_elapsed         | 2515        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.014548251 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.476       |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 7.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 63          |
# |    time_elapsed         | 2556        |
# |    total_timesteps      | 258048      |
# | train/                  |             |
# |    approx_kl            | 0.020306606 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.4         |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.000201   |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 64          |
# |    time_elapsed         | 2597        |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.022611722 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0005      |
# ...
# |    iterations           | 835         |
# |    time_elapsed         | 34083       |
# |    total_timesteps      | 3420160     |
# | train/                  |             |
# |    approx_kl            | 0.021840956 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 4.06        |
# |    n_updates            | 8340        |
# |    policy_gradient_loss | -0.000703   |
# |    value_loss           | 45.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 836         |
# |    time_elapsed         | 34123       |
# |    total_timesteps      | 3424256     |
# | train/                  |             |
# |    approx_kl            | 0.021273313 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 5.97        |
# |    n_updates            | 8350        |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 837         |
# |    time_elapsed         | 34164       |
# |    total_timesteps      | 3428352     |
# | train/                  |             |
# |    approx_kl            | 0.043654956 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.52        |
# |    n_updates            | 8360        |
# |    policy_gradient_loss | 0.00621     |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 838         |
# |    time_elapsed         | 34205       |
# |    total_timesteps      | 3432448     |
# | train/                  |             |
# |    approx_kl            | 0.015866447 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.1         |
# |    n_updates            | 8370        |
# |    policy_gradient_loss | 0.00273     |
# |    value_loss           | 43          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 839        |
# |    time_elapsed         | 34245      |
# |    total_timesteps      | 3436544    |
# | train/                  |            |
# |    approx_kl            | 0.02193789 |
# |    clip_fraction        | 0.0481     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.951     |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 25.8       |
# |    n_updates            | 8380       |
# |    policy_gradient_loss | 0.00754    |
# |    value_loss           | 57.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 840         |
# |    time_elapsed         | 34286       |
# |    total_timesteps      | 3440640     |
# | train/                  |             |
# |    approx_kl            | 0.030111374 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.953      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 16.4        |
# |    n_updates            | 8390        |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 58.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 841        |
# |    time_elapsed         | 34326      |
# |    total_timesteps      | 3444736    |
# | train/                  |            |
# |    approx_kl            | 0.01224892 |
# |    clip_fraction        | 0.0515     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.997     |
# |    explained_variance   | 0.826      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 2.77       |
# |    n_updates            | 8400       |
# |    policy_gradient_loss | -0.00564   |
# |    value_loss           | 46.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 842         |
# |    time_elapsed         | 34367       |
# |    total_timesteps      | 3448832     |
# | train/                  |             |
# |    approx_kl            | 0.022664573 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 4.64        |
# |    n_updates            | 8410        |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 35.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 843        |
# |    time_elapsed         | 34408      |
# |    total_timesteps      | 3452928    |
# | train/                  |            |
# |    approx_kl            | 0.02124843 |
# |    clip_fraction        | 0.0625     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.999     |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0005     |
# |    loss                 | 8.87       |
# |    n_updates            | 8420       |
# |    policy_gradient_loss | -0.00455   |
# |    value_loss           | 29.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 844         |
# |    time_elapsed         | 34450       |
# |    total_timesteps      | 3457024     |
# | train/                  |             |
# |    approx_kl            | 0.016868863 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 8.2         |
# |    n_updates            | 8430        |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 30          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 845        |
# |    time_elapsed         | 34492      |
# |    total_timesteps      | 3461120    |
# | train/                  |            |
# |    approx_kl            | 0.00864822 |
# |    clip_fraction        | 0.0404     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.966     |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 3.67       |
# |    n_updates            | 8440       |
# |    policy_gradient_loss | -0.00149   |
# |    value_loss           | 56.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 846         |
# |    time_elapsed         | 34532       |
# |    total_timesteps      | 3465216     |
# | train/                  |             |
# |    approx_kl            | 0.014955658 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 13.3        |
# |    n_updates            | 8450        |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 56.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 847         |
# |    time_elapsed         | 34573       |
# |    total_timesteps      | 3469312     |
# | train/                  |             |
# |    approx_kl            | 0.022702537 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 14          |
# |    n_updates            | 8460        |
# |    policy_gradient_loss | 0.00162     |
# |    value_loss           | 87.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 848         |
# |    time_elapsed         | 34613       |
# |    total_timesteps      | 3473408     |
# | train/                  |             |
# |    approx_kl            | 0.029505786 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.43        |
# |    n_updates            | 8470        |
# |    policy_gradient_loss | 0.00329     |
# |    value_loss           | 47.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 849         |
# |    time_elapsed         | 34654       |
# |    total_timesteps      | 3477504     |
# | train/                  |             |
# |    approx_kl            | 0.013474049 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 4.1         |
# |    n_updates            | 8480        |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 27.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 850         |
# |    time_elapsed         | 34695       |
# |    total_timesteps      | 3481600     |
# | train/                  |             |
# |    approx_kl            | 0.014391265 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 5.33        |
# |    n_updates            | 8490        |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 851         |
# |    time_elapsed         | 34736       |
# |    total_timesteps      | 3485696     |
# | train/                  |             |
# |    approx_kl            | 0.026451875 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.85        |
# |    n_updates            | 8500        |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 30.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 852        |
# |    time_elapsed         | 34777      |
# |    total_timesteps      | 3489792    |
# | train/                  |            |
# |    approx_kl            | 0.01582335 |
# |    clip_fraction        | 0.0497     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 5.7        |
# |    n_updates            | 8510       |
# |    policy_gradient_loss | -0.00491   |
# |    value_loss           | 33         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 853         |
# |    time_elapsed         | 34819       |
# |    total_timesteps      | 3493888     |
# | train/                  |             |
# |    approx_kl            | 0.022043569 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.977      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 4.31        |
# |    n_updates            | 8520        |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 854         |
# |    time_elapsed         | 34860       |
# |    total_timesteps      | 3497984     |
# | train/                  |             |
# |    approx_kl            | 0.022501914 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 5.36        |
# |    n_updates            | 8530        |
# |    policy_gradient_loss | 0.00502     |
# |    value_loss           | 48.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 855         |
# |    time_elapsed         | 34901       |
# |    total_timesteps      | 3502080     |
# | train/                  |             |
# |    approx_kl            | 0.040015027 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.886      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 62.2        |
# |    n_updates            | 8540        |
# |    policy_gradient_loss | -0.000384   |
# |    value_loss           | 72.8        |
# -----------------------------------------
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
