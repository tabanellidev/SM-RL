# %%
import gym

#Import game
import gym_super_mario_bros

#Import Joypad
from nes_py.wrappers import JoypadSpace

#Import Controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

#FrameStacking e GreyScaling
from gym.wrappers import GrayScaleObservation

#Vectorization
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv

#Graphs
from matplotlib import pyplot as plt

import os

from stable_baselines3 import DQN

#To save models
from stable_baselines3.common.callbacks import BaseCallback

from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

import torch.nn as nn
import torch as th

from gymnasium import spaces

# %%
# [1] - Setup base environment
env = gym_super_mario_bros.make("SuperMarioBros-v0", render_mode='human', apply_api_compatibility=True)
#256 possible actions
print(env.action_space)

# [2] - Simplify the controls, with wrapping the model will have only 7 possible actions
env = JoypadSpace(env, SIMPLE_MOVEMENT)
print(env.action_space)

# [3] - Grayscale
env = GrayScaleObservation(env, keep_dim=True)

# [4] - Wrap inside a dummy envorinment
env = DummyVecEnv([lambda: env])

# [5] - Stack four frames
env = VecFrameStack(env, 4, channels_order='last')

#JoypadSpace doesn't correctly override the reset() method of Wrapper.
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
# Out:
# Discrete(256)
# Discrete(7)
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
checkpoint_directory = './train/'
log_dir = './logs/'

callback = TrainAndLoggingCallback(check_freq=100000,save_path=checkpoint_directory)

# %%
model = DQN('CnnPolicy', env, verbose=1, tensorboard_log=log_dir, learning_rate=0.00004, batch_size=250, learning_starts=5000, buffer_size=5000)

print(model.policy)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# CnnPolicy(
#   (q_net): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=46592, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=7, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=46592, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=7, bias=True)
#     )
#   )
# )

# %%
model.learn(total_timesteps=3500000, callback=callback)
# Out:
# Logging to ./logs/DQN_1
# c:\Users\Taba\Desktop\Super Mario\mlenv\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 51       |
# |    time_elapsed     | 1422     |
# |    total_timesteps  | 73261    |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0715   |
# |    n_updates        | 17065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 48       |
# |    time_elapsed     | 2882     |
# |    total_timesteps  | 140647   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.039    |
# |    n_updates        | 33911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 47       |
# |    time_elapsed     | 4233     |
# |    total_timesteps  | 201564   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.0498   |
# |    n_updates        | 49140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 46       |
# |    time_elapsed     | 5263     |
# |    total_timesteps  | 246750   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.139    |
# |    n_updates        | 60437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.237    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 46       |
# |    time_elapsed     | 6061     |
# |    total_timesteps  | 281239   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.175    |
# |    n_updates        | 69059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 46       |
# |    time_elapsed     | 6437     |
# |    total_timesteps  | 297336   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.342    |
# |    n_updates        | 73083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 46       |
# |    time_elapsed     | 6758     |
# |    total_timesteps  | 311011   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.451    |
# |    n_updates        | 76502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.119    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 45       |
# |    time_elapsed     | 7080     |
# |    total_timesteps  | 324656   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.334    |
# |    n_updates        | 79913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0875   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 45       |
# |    time_elapsed     | 7352     |
# |    total_timesteps  | 336200   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.562    |
# |    n_updates        | 82799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 45       |
# |    time_elapsed     | 7708     |
# |    total_timesteps  | 351422   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.375    |
# |    n_updates        | 86605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 45       |
# |    time_elapsed     | 7895     |
# |    total_timesteps  | 359407   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.944    |
# |    n_updates        | 88601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 45       |
# |    time_elapsed     | 8072     |
# |    total_timesteps  | 366950   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.319    |
# |    n_updates        | 90487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 45       |
# |    time_elapsed     | 8217     |
# |    total_timesteps  | 373113   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.03     |
# |    n_updates        | 92028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 45       |
# |    time_elapsed     | 8396     |
# |    total_timesteps  | 380784   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.598    |
# |    n_updates        | 93945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 45       |
# |    time_elapsed     | 8686     |
# |    total_timesteps  | 393121   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.473    |
# |    n_updates        | 97030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 45       |
# |    time_elapsed     | 8941     |
# |    total_timesteps  | 403845   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.426    |
# |    n_updates        | 99711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 45       |
# |    time_elapsed     | 9235     |
# |    total_timesteps  | 416239   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.755    |
# |    n_updates        | 102809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 44       |
# |    time_elapsed     | 9579     |
# |    total_timesteps  | 430730   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.456    |
# |    n_updates        | 106432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 44       |
# |    time_elapsed     | 9856     |
# |    total_timesteps  | 442393   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.473    |
# |    n_updates        | 109348   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 44       |
# |    time_elapsed     | 10103    |
# |    total_timesteps  | 452750   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.417    |
# |    n_updates        | 111937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 44       |
# |    time_elapsed     | 10324    |
# |    total_timesteps  | 462111   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.62     |
# |    n_updates        | 114277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 44       |
# |    time_elapsed     | 10558    |
# |    total_timesteps  | 471950   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.411    |
# |    n_updates        | 116737   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 44       |
# |    time_elapsed     | 10725    |
# |    total_timesteps  | 479016   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.663    |
# |    n_updates        | 118503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 44       |
# |    time_elapsed     | 10855    |
# |    total_timesteps  | 484543   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.716    |
# |    n_updates        | 119885   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 44       |
# |    time_elapsed     | 11033    |
# |    total_timesteps  | 492092   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.793    |
# |    n_updates        | 121772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 44       |
# |    time_elapsed     | 11299    |
# |    total_timesteps  | 503192   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.675    |
# |    n_updates        | 124547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 44       |
# |    time_elapsed     | 11519    |
# |    total_timesteps  | 512078   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.711    |
# |    n_updates        | 126769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 44       |
# |    time_elapsed     | 11800    |
# |    total_timesteps  | 523355   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.02     |
# |    n_updates        | 129588   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 44       |
# |    time_elapsed     | 12010    |
# |    total_timesteps  | 531828   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.733    |
# |    n_updates        | 131706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 44       |
# |    time_elapsed     | 12290    |
# |    total_timesteps  | 543058   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.653    |
# |    n_updates        | 134514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 44       |
# |    time_elapsed     | 12501    |
# |    total_timesteps  | 551528   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.859    |
# |    n_updates        | 136631   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 43       |
# |    time_elapsed     | 12941    |
# |    total_timesteps  | 569311   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.141    |
# |    n_updates        | 141077   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 43       |
# |    time_elapsed     | 13196    |
# |    total_timesteps  | 579669   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.562    |
# |    n_updates        | 143667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 43       |
# |    time_elapsed     | 13404    |
# |    total_timesteps  | 588088   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.796    |
# |    n_updates        | 145771   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 43       |
# |    time_elapsed     | 13861    |
# |    total_timesteps  | 606411   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.342    |
# |    n_updates        | 150352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 43       |
# |    time_elapsed     | 14124    |
# |    total_timesteps  | 616615   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.718    |
# |    n_updates        | 152903   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 43       |
# |    time_elapsed     | 14432    |
# |    total_timesteps  | 628586   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.435    |
# |    n_updates        | 155896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 43       |
# |    time_elapsed     | 14624    |
# |    total_timesteps  | 636058   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.911    |
# |    n_updates        | 157764   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 43       |
# |    time_elapsed     | 14803    |
# |    total_timesteps  | 643181   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.627    |
# |    n_updates        | 159545   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 43       |
# |    time_elapsed     | 14987    |
# |    total_timesteps  | 650351   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.2      |
# |    n_updates        | 161337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 43       |
# |    time_elapsed     | 15150    |
# |    total_timesteps  | 656793   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.787    |
# |    n_updates        | 162948   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 43       |
# |    time_elapsed     | 15458    |
# |    total_timesteps  | 669063   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.836    |
# |    n_updates        | 166015   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 43       |
# |    time_elapsed     | 15770    |
# |    total_timesteps  | 681566   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.14     |
# |    n_updates        | 169141   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 43       |
# |    time_elapsed     | 16104    |
# |    total_timesteps  | 694833   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.338    |
# |    n_updates        | 172458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 43       |
# |    time_elapsed     | 16417    |
# |    total_timesteps  | 707081   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.03     |
# |    n_updates        | 175520   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 43       |
# |    time_elapsed     | 16609    |
# |    total_timesteps  | 714632   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.839    |
# |    n_updates        | 177407   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 42       |
# |    time_elapsed     | 16729    |
# |    total_timesteps  | 719292   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.14     |
# |    n_updates        | 178572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 42       |
# |    time_elapsed     | 17076    |
# |    total_timesteps  | 732759   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.436    |
# |    n_updates        | 181939   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 42       |
# |    time_elapsed     | 17318    |
# |    total_timesteps  | 742181   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.561    |
# |    n_updates        | 184295   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 42       |
# |    time_elapsed     | 17716    |
# |    total_timesteps  | 757930   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.416    |
# |    n_updates        | 188232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 42       |
# |    time_elapsed     | 18211    |
# |    total_timesteps  | 777472   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.505    |
# |    n_updates        | 193117   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 42       |
# |    time_elapsed     | 18465    |
# |    total_timesteps  | 787707   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.23     |
# |    n_updates        | 195676   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 42       |
# |    time_elapsed     | 18775    |
# |    total_timesteps  | 800140   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.19     |
# |    n_updates        | 198784   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 42       |
# |    time_elapsed     | 18987    |
# |    total_timesteps  | 808367   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.718    |
# |    n_updates        | 200841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 42       |
# |    time_elapsed     | 19233    |
# |    total_timesteps  | 818101   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.288    |
# |    n_updates        | 203275   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 42       |
# |    time_elapsed     | 19733    |
# |    total_timesteps  | 838147   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.279    |
# |    n_updates        | 208286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 42       |
# |    time_elapsed     | 20003    |
# |    total_timesteps  | 849093   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.482    |
# |    n_updates        | 211023   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 42       |
# |    time_elapsed     | 20372    |
# |    total_timesteps  | 864064   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.8      |
# |    n_updates        | 214765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 42       |
# |    time_elapsed     | 20529    |
# |    total_timesteps  | 870442   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.972    |
# |    n_updates        | 216360   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 42       |
# |    time_elapsed     | 20685    |
# |    total_timesteps  | 876550   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.755    |
# |    n_updates        | 217887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 42       |
# |    time_elapsed     | 20993    |
# |    total_timesteps  | 888569   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.07     |
# |    n_updates        | 220892   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 42       |
# |    time_elapsed     | 21122    |
# |    total_timesteps  | 893765   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.882    |
# |    n_updates        | 222191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 42       |
# |    time_elapsed     | 21385    |
# |    total_timesteps  | 904207   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.44     |
# |    n_updates        | 224801   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 42       |
# |    time_elapsed     | 21585    |
# |    total_timesteps  | 912409   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.861    |
# |    n_updates        | 226852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 42       |
# |    time_elapsed     | 21810    |
# |    total_timesteps  | 921719   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.555    |
# |    n_updates        | 229179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 42       |
# |    time_elapsed     | 22090    |
# |    total_timesteps  | 933341   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.34     |
# |    n_updates        | 232085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 42       |
# |    time_elapsed     | 22469    |
# |    total_timesteps  | 949028   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.15     |
# |    n_updates        | 236006   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 42       |
# |    time_elapsed     | 22681    |
# |    total_timesteps  | 957783   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.492    |
# |    n_updates        | 238195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 42       |
# |    time_elapsed     | 22811    |
# |    total_timesteps  | 963186   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.99     |
# |    n_updates        | 239546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 42       |
# |    time_elapsed     | 23035    |
# |    total_timesteps  | 972412   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.759    |
# |    n_updates        | 241852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 42       |
# |    time_elapsed     | 23487    |
# |    total_timesteps  | 991053   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.215    |
# |    n_updates        | 246513   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 42       |
# |    time_elapsed     | 23678    |
# |    total_timesteps  | 998929   |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.14     |
# |    n_updates        | 248482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 42       |
# |    time_elapsed     | 23849    |
# |    total_timesteps  | 1006008  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.727    |
# |    n_updates        | 250251   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 42       |
# |    time_elapsed     | 24111    |
# |    total_timesteps  | 1016696  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.727    |
# |    n_updates        | 252923   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 42       |
# |    time_elapsed     | 24226    |
# |    total_timesteps  | 1021249  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.888    |
# |    n_updates        | 254062   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 42       |
# |    time_elapsed     | 24414    |
# |    total_timesteps  | 1028567  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.32     |
# |    n_updates        | 255891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 42       |
# |    time_elapsed     | 24596    |
# |    total_timesteps  | 1035702  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.606    |
# |    n_updates        | 257675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 42       |
# |    time_elapsed     | 24745    |
# |    total_timesteps  | 1041685  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.738    |
# |    n_updates        | 259171   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 42       |
# |    time_elapsed     | 25127    |
# |    total_timesteps  | 1056961  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.692    |
# |    n_updates        | 262990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 42       |
# |    time_elapsed     | 25367    |
# |    total_timesteps  | 1066623  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.43     |
# |    n_updates        | 265405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 42       |
# |    time_elapsed     | 25662    |
# |    total_timesteps  | 1078556  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.655    |
# |    n_updates        | 268388   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 42       |
# |    time_elapsed     | 25895    |
# |    total_timesteps  | 1087934  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.622    |
# |    n_updates        | 270733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 42       |
# |    time_elapsed     | 26063    |
# |    total_timesteps  | 1094667  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.898    |
# |    n_updates        | 272416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 41       |
# |    time_elapsed     | 26151    |
# |    total_timesteps  | 1098231  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1        |
# |    n_updates        | 273307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 41       |
# |    time_elapsed     | 26367    |
# |    total_timesteps  | 1106955  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.719    |
# |    n_updates        | 275488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 41       |
# |    time_elapsed     | 26631    |
# |    total_timesteps  | 1117702  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.716    |
# |    n_updates        | 278175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 41       |
# |    time_elapsed     | 26898    |
# |    total_timesteps  | 1128486  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.51     |
# |    n_updates        | 280871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 41       |
# |    time_elapsed     | 27158    |
# |    total_timesteps  | 1138899  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.32     |
# |    n_updates        | 283474   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 41       |
# |    time_elapsed     | 27377    |
# |    total_timesteps  | 1147819  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.572    |
# |    n_updates        | 285704   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 41       |
# |    time_elapsed     | 27621    |
# |    total_timesteps  | 1157805  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.648    |
# |    n_updates        | 288201   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 41       |
# |    time_elapsed     | 27861    |
# |    total_timesteps  | 1167592  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.904    |
# |    n_updates        | 290647   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 41       |
# |    time_elapsed     | 28074    |
# |    total_timesteps  | 1176293  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.906    |
# |    n_updates        | 292823   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 41       |
# |    time_elapsed     | 28500    |
# |    total_timesteps  | 1193972  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.653    |
# |    n_updates        | 297242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 41       |
# |    time_elapsed     | 28667    |
# |    total_timesteps  | 1200845  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.16     |
# |    n_updates        | 298961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 41       |
# |    time_elapsed     | 29098    |
# |    total_timesteps  | 1218354  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.468    |
# |    n_updates        | 303338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 41       |
# |    time_elapsed     | 29388    |
# |    total_timesteps  | 1230086  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.859    |
# |    n_updates        | 306271   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 41       |
# |    time_elapsed     | 29708    |
# |    total_timesteps  | 1242950  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.05     |
# |    n_updates        | 309487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 41       |
# |    time_elapsed     | 29935    |
# |    total_timesteps  | 1252059  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.65     |
# |    n_updates        | 311764   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 41       |
# |    time_elapsed     | 30121    |
# |    total_timesteps  | 1259501  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.441    |
# |    n_updates        | 313625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 41       |
# |    time_elapsed     | 30392    |
# |    total_timesteps  | 1270369  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.521    |
# |    n_updates        | 316342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 41       |
# |    time_elapsed     | 30748    |
# |    total_timesteps  | 1284565  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.553    |
# |    n_updates        | 319891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 41       |
# |    time_elapsed     | 31013    |
# |    total_timesteps  | 1295137  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.733    |
# |    n_updates        | 322534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 41       |
# |    time_elapsed     | 31263    |
# |    total_timesteps  | 1305112  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.714    |
# |    n_updates        | 325027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 41       |
# |    time_elapsed     | 31576    |
# |    total_timesteps  | 1317237  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.449    |
# |    n_updates        | 328059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 41       |
# |    time_elapsed     | 31962    |
# |    total_timesteps  | 1332450  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.492    |
# ...
# |    n_updates        | 402665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 41       |
# |    time_elapsed     | 39546    |
# |    total_timesteps  | 1624241  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.585    |
# |    n_updates        | 404810   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 41       |
# |    time_elapsed     | 39878    |
# |    total_timesteps  | 1637043  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.324    |
# |    n_updates        | 408010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 41       |
# |    time_elapsed     | 40022    |
# |    total_timesteps  | 1642680  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.584    |
# |    n_updates        | 409419   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 41       |
# |    time_elapsed     | 40235    |
# |    total_timesteps  | 1650848  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.587    |
# |    n_updates        | 411461   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 41       |
# |    time_elapsed     | 40428    |
# |    total_timesteps  | 1658520  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.834    |
# |    n_updates        | 413379   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 41       |
# |    time_elapsed     | 40745    |
# |    total_timesteps  | 1671250  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.617    |
# |    n_updates        | 416562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 41       |
# |    time_elapsed     | 41034    |
# |    total_timesteps  | 1682965  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.263    |
# |    n_updates        | 419491   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 41       |
# |    time_elapsed     | 41237    |
# |    total_timesteps  | 1691137  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.651    |
# |    n_updates        | 421534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 40       |
# |    time_elapsed     | 41616    |
# |    total_timesteps  | 1706206  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.492    |
# |    n_updates        | 425301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 40       |
# |    time_elapsed     | 41741    |
# |    total_timesteps  | 1711002  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.821    |
# |    n_updates        | 426500   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 40       |
# |    time_elapsed     | 42092    |
# |    total_timesteps  | 1724605  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.367    |
# |    n_updates        | 429901   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 40       |
# |    time_elapsed     | 42432    |
# |    total_timesteps  | 1737418  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.8      |
# |    n_updates        | 433104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 40       |
# |    time_elapsed     | 42677    |
# |    total_timesteps  | 1746462  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.821    |
# |    n_updates        | 435365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 40       |
# |    time_elapsed     | 43066    |
# |    total_timesteps  | 1761181  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.448    |
# |    n_updates        | 439045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 40       |
# |    time_elapsed     | 43292    |
# |    total_timesteps  | 1769832  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.512    |
# |    n_updates        | 441207   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 40       |
# |    time_elapsed     | 43457    |
# |    total_timesteps  | 1776084  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.741    |
# |    n_updates        | 442770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 40       |
# |    time_elapsed     | 43694    |
# |    total_timesteps  | 1785170  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.594    |
# |    n_updates        | 445042   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 40       |
# |    time_elapsed     | 43932    |
# |    total_timesteps  | 1794452  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.373    |
# |    n_updates        | 447362   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 40       |
# |    time_elapsed     | 44234    |
# |    total_timesteps  | 1806196  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.331    |
# |    n_updates        | 450298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 40       |
# |    time_elapsed     | 44560    |
# |    total_timesteps  | 1818716  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.934    |
# |    n_updates        | 453428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 40       |
# |    time_elapsed     | 45123    |
# |    total_timesteps  | 1840373  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.435    |
# |    n_updates        | 458843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 40       |
# |    time_elapsed     | 45435    |
# |    total_timesteps  | 1852178  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.343    |
# |    n_updates        | 461794   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 40       |
# |    time_elapsed     | 45621    |
# |    total_timesteps  | 1859236  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.61     |
# |    n_updates        | 463558   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 40       |
# |    time_elapsed     | 45787    |
# |    total_timesteps  | 1865636  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.671    |
# |    n_updates        | 465158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 40       |
# |    time_elapsed     | 46055    |
# |    total_timesteps  | 1876205  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.628    |
# |    n_updates        | 467801   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 40       |
# |    time_elapsed     | 46394    |
# |    total_timesteps  | 1889384  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.625    |
# |    n_updates        | 471095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 40       |
# |    time_elapsed     | 46711    |
# |    total_timesteps  | 1901796  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.595    |
# |    n_updates        | 474198   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 40       |
# |    time_elapsed     | 46988    |
# |    total_timesteps  | 1913005  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.389    |
# |    n_updates        | 477001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 40       |
# |    time_elapsed     | 47181    |
# |    total_timesteps  | 1920708  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 1.5      |
# |    n_updates        | 478926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 40       |
# |    time_elapsed     | 47552    |
# |    total_timesteps  | 1935080  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.353    |
# |    n_updates        | 482519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 40       |
# |    time_elapsed     | 47839    |
# |    total_timesteps  | 1946245  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.467    |
# |    n_updates        | 485311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 40       |
# |    time_elapsed     | 48282    |
# |    total_timesteps  | 1963052  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.382    |
# |    n_updates        | 489512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 40       |
# |    time_elapsed     | 48559    |
# |    total_timesteps  | 1973760  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.427    |
# |    n_updates        | 492189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 40       |
# |    time_elapsed     | 48860    |
# |    total_timesteps  | 1985324  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.53     |
# |    n_updates        | 495080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 40       |
# |    time_elapsed     | 49104    |
# |    total_timesteps  | 1994468  |
# | train/              |          |
# |    learning_rate    | 4e-05    |
# |    loss             | 0.471    |
# |    n_updates        | 497366   |
# ----------------------------------
